# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import xarray as xr
import rioxarray as rxr
import rasterio as rio
from rasterio.plot import show
import matplotlib.pyplot as plt
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep




import glob
import os

# %%
path = "D:/RS_Project_with_data/data/images/2016-05-15.tif"

# %%
img = rxr.open_rasterio(path)
img[0]
# Out:
# <xarray.DataArray (y: 1416, x: 1462)>
# [2070192 values with dtype=int16]
# Coordinates:
#     band         int32 1
#   * x            (x) float64 5.951e+05 5.951e+05 ... 6.097e+05 6.097e+05
#   * y            (y) float64 5.665e+06 5.665e+06 ... 5.651e+06 5.651e+06
#     spatial_ref  int32 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B01', 'B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', ...

# %%
img.values
# Out:
# array([[[ 814,  814,  358, ...,  435,  389,  389],
#         [ 814,  814,  358, ...,  435,  389,  389],
#         [ 814,  814,  358, ...,  435,  389,  389],
#         ...,
#         [3397, 3397, 2103, ..., 4680, 4587, 4587],
#         [3397, 3397, 2103, ..., 4680, 4587, 4587],
#         [3397, 3397, 2103, ..., 4680, 4587, 4587]],
#
#        [[ 881,  961,  796, ...,  442,  375,  313],
#         [ 656,  829,  807, ...,  462,  305,  293],
#         [ 451,  589,  667, ...,  438,  281,  279],
#         ...,
#         [3560, 4140, 2900, ..., 3656, 3654, 3709],
#         [2316, 2956, 2190, ..., 3632, 3642, 3715],
#         [3130, 2500, 1476, ..., 3636, 3719, 3921]],
#
#        [[1118,  917,  812, ...,  949,  667,  575],
#         [1034,  915,  852, ..., 1180,  663,  586],
#         [ 824,  880,  791, ..., 1271,  613,  524],
#         ...,
#         [3692, 4152, 3034, ..., 3378, 3359, 3333],
#         [2430, 3052, 2338, ..., 3346, 3354, 3417],
#         [3034, 2396, 1760, ..., 3366, 3403, 3508]],
#
#        ...,
#
#        [[   4,    4,    4, ...,    4,    4,    4],
#         [   4,    4,    4, ...,    4,    4,    4],
#         [   4,    4,    4, ...,    4,    4,    4],
#         ...,
#         [   9,    9,    8, ...,    9,    9,    9],
#         [   9,    9,    8, ...,    9,    9,    9],
#         [   9,    9,    8, ...,    9,    9,    9]],
#
#        [[ 113,  113,  113, ...,  110,  110,  110],
#         [ 113,  113,  113, ...,  110,  110,  110],
#         [ 113,  113,  113, ...,  110,  110,  110],
#         ...,
#         [ 115,  115,  115, ...,  109,  109,  109],
#         [ 115,  115,  115, ...,  109,  109,  109],
#         [ 115,  115,  115, ...,  109,  109,  109]],
#
#        [[ 822,  822,  830, ..., 1149,  794,  794],
#         [ 867,  867,  884, ..., 1149,  853,  853],
#         [ 867,  867,  884, ..., 1149,  853,  853],
#         ...,
#         [ 822,  822,  822, ...,  844,  844,  844],
#         [ 822,  822,  822, ...,  844,  844,  844],
#         [ 822,  822,  822, ...,  844,  844,  844]]], dtype=int16)

# %%
img2 = rio.open(path)
img2 = img2.read()
# Out:
# array([[1118,  917,  812, ...,  949,  667,  575],
#        [1034,  915,  852, ..., 1180,  663,  586],
#        [ 824,  880,  791, ..., 1271,  613,  524],
#        ...,
#        [3692, 4152, 3034, ..., 3378, 3359, 3333],
#        [2430, 3052, 2338, ..., 3346, 3354, 3417],
#        [3034, 2396, 1760, ..., 3366, 3403, 3508]], dtype=int16)

# %%
plt.imshow(img2[i])
